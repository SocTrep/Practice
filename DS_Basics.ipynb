# %% [markdown]
# <a href="https://colab.research.google.com/github/SocTrep/Practice/blob/main/DS_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ucimlrepo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
phiusiil_phishing_url_website = fetch_ucirepo(id=967)

# data (as pandas dataframes)
X = phiusiil_phishing_url_website.data.features
y = phiusiil_phishing_url_website.data.targets

# metadata
#print(phiusiil_phishing_url_website.metadata)

# variable information
#print(phiusiil_phishing_url_website.variables)

# %% [markdown]
# Label 1 corresponds to a legitimate URL, label 0 to a phishing URL
# http://archive.ics.uci.edu/dataset/967/phiusiil+phishing+url+dataset

# %%
X.head()
# Out:
#                                   URL  URLLength                      Domain  \
# 0    https://www.southbankmosaics.com         31    www.southbankmosaics.com
# 1            https://www.uni-mainz.de         23            www.uni-mainz.de
# 2      https://www.voicefmradio.co.uk         29      www.voicefmradio.co.uk
# 3         https://www.sfnmjournal.com         26         www.sfnmjournal.com
# 4  https://www.rewildingargentina.org         33  www.rewildingargentina.org
#
#    DomainLength  IsDomainIP  TLD  URLSimilarityIndex  CharContinuationRate  \
# 0            24           0  com               100.0              1.000000
# 1            16           0   de               100.0              0.666667
# 2            22           0   uk               100.0              0.866667
# 3            19           0  com               100.0              1.000000
# 4            26           0  org               100.0              1.000000
#
# ...

# %%
all_data = pd.concat([X,y], axis=1)
all_data.query('label == 0 and Crypto == 1').head(n=10)
# Out:
#                                                     URL  URLLength  \
# 295                          https://uniswap-event.org/         25
# 956                           http://www.crypto-pool.fr         24
# 1354             https://opensea-nftx.godaddysites.com/         37
# 2821                           http://www.jacobdrop.xyz         23
# 2857                    http://www.intershare.zapto.net         30
# 2988                          http://www.cryptobara.com         24
# 3034  https://updatemetamask.net/?gclid=eaiaiqobchmi...         69
# 3774                 http://cryptofreejioidea.code.blog         33
# 3820                            http://www.coinhive.com         22
# 3874                            http://crypto-nodes.org         23
#
#                              Domain  DomainLength  IsDomainIP   TLD  \
# 295               uniswap-event.org            17           0   org
# 956              www.crypto-pool.fr            18           0    fr
# ...

# %%
df = all_data.copy()

# %%
df['Crypto']
# Out:
# 0         0
# 1         0
# 2         0
# 3         1
# 4         0
#          ..
# 235790    0
# 235791    0
# 235792    0
# 235793    0
# 235794    0
# Name: Crypto, Length: 235795, dtype: int64

# %%
df.iloc[:5]
# Out:
#                                   URL  URLLength                      Domain  \
# 0    https://www.southbankmosaics.com         31    www.southbankmosaics.com
# 1            https://www.uni-mainz.de         23            www.uni-mainz.de
# 2      https://www.voicefmradio.co.uk         29      www.voicefmradio.co.uk
# 3         https://www.sfnmjournal.com         26         www.sfnmjournal.com
# 4  https://www.rewildingargentina.org         33  www.rewildingargentina.org
#
#    DomainLength  IsDomainIP  TLD  URLSimilarityIndex  CharContinuationRate  \
# 0            24           0  com               100.0              1.000000
# 1            16           0   de               100.0              0.666667
# 2            22           0   uk               100.0              0.866667
# 3            19           0  com               100.0              1.000000
# 4            26           0  org               100.0              1.000000
#
# ...

# %%
df[2:5]
# Out:
#                                   URL  URLLength                      Domain  \
# 2      https://www.voicefmradio.co.uk         29      www.voicefmradio.co.uk
# 3         https://www.sfnmjournal.com         26         www.sfnmjournal.com
# 4  https://www.rewildingargentina.org         33  www.rewildingargentina.org
#
#    DomainLength  IsDomainIP  TLD  URLSimilarityIndex  CharContinuationRate  \
# 2            22           0   uk               100.0              0.866667
# 3            19           0  com               100.0              1.000000
# 4            26           0  org               100.0              1.000000
#
#    TLDLegitimateProb  URLCharProb  ...  Pay  Crypto  HasCopyrightInfo  \
# 2           0.028555     0.064129  ...    0       0                 1
# 3           0.522907     0.057606  ...    1       1                 1
# 4           0.079963     0.059441  ...    1       0                 1
#
# ...

# %%
df.iloc[2:5, 7:9]
# Out:
#    CharContinuationRate  TLDLegitimateProb
# 2              0.866667           0.028555
# 3              1.000000           0.522907
# 4              1.000000           0.079963

# %%
df.loc['Crypto']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2332c7ac8092> in <cell line: 0>()
# ----> 1 df.loc['Crypto']
#
# NameError: name 'df' is not defined
